# %%
import pandas as pd

# %%
def test_run():
    df=pd.read_csv("data/HCP.csv")
    print (df) #print entire dataframe

# %%
if __name__ =="__main__":
    test_run()
# Out:
#           Date       Open       High        Low      Close  Adj Close   Volume
# 0   2017-11-01  25.870001  26.139999  25.760000  26.020000  25.662767  5109700
# 1   2017-11-02  26.969999  27.620001  26.709999  26.950001  26.580000  8229900
# 2   2017-11-03  26.510000  27.150000  26.510000  27.139999  27.139999  4215100
# 3   2017-11-06  27.170000  27.360001  26.840000  26.840000  26.840000  4193300
# 4   2017-11-07  26.799999  27.080000  26.750000  27.000000  27.000000  3548400
# 5   2017-11-08  26.910000  27.070000  26.790001  26.990000  26.990000  5084400
# 6   2017-11-09  26.830000  27.219999  26.830000  27.020000  27.020000  3623900
# 7   2017-11-10  26.850000  27.360001  26.760000  27.010000  27.010000  3328400
# 8   2017-11-13  27.049999  27.309999  27.010000  27.230000  27.230000  3267000
# 9   2017-11-14  27.180000  27.340000  27.020000  27.020000  27.020000  3800700
# 10  2017-11-15  26.980000  27.100000  26.500000  26.910000  26.910000  4103400
# 11  2017-11-16  26.959999  27.010000  26.660000  26.840000  26.840000  4430500
# 12  2017-11-17  26.750000  26.900000  26.740000  26.799999  26.799999  2769700
# 13  2017-11-20  26.799999  26.870001  26.540001  26.799999  26.799999  3211700
# 14  2017-11-21  26.870001  26.930000  26.760000  26.799999  26.799999  3468500
# 15  2017-11-22  26.760000  26.930000  26.709999  26.709999  26.709999  2552100
# 16  2017-11-24  26.719999  27.000000  26.719999  26.879999  26.879999   880700
# 17  2017-11-27  26.870001  26.930000  26.690001  26.690001  26.690001  3106000
# 18  2017-11-28  26.700001  26.780001  26.410000  26.549999  26.549999  2566600
# 19  2017-11-29  26.540001  26.950001  26.379999  26.900000  26.900000  3358000
# 20  2017-11-30  26.830000  26.850000  26.299999  26.440001  26.440001  4863100

# %%
def test_run():
    df=pd.read_csv("data/HCP.csv")
    print (df.head())

# %%
test_run()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2017-11-01  25.870001  26.139999  25.760000  26.020000  25.662767  5109700
# 1  2017-11-02  26.969999  27.620001  26.709999  26.950001  26.580000  8229900
# 2  2017-11-03  26.510000  27.150000  26.510000  27.139999  27.139999  4215100
# 3  2017-11-06  27.170000  27.360001  26.840000  26.840000  26.840000  4193300
# 4  2017-11-07  26.799999  27.080000  26.750000  27.000000  27.000000  3548400

# %%
def test_run():
    df=pd.read_csv("data/HCP.csv")
    print (df.tail())

# %%
test_run()
# Out:
#           Date       Open       High        Low      Close  Adj Close   Volume
# 16  2017-11-24  26.719999  27.000000  26.719999  26.879999  26.879999   880700
# 17  2017-11-27  26.870001  26.930000  26.690001  26.690001  26.690001  3106000
# 18  2017-11-28  26.700001  26.780001  26.410000  26.549999  26.549999  2566600
# 19  2017-11-29  26.540001  26.950001  26.379999  26.900000  26.900000  3358000
# 20  2017-11-30  26.830000  26.850000  26.299999  26.440001  26.440001  4863100

# %%
import matplotlib.pyplot as plt

# %%
def test_run():
    df=pd.read_csv("data/HCP.csv")
    print (df["Adj Close"])
    df["Adj Close"].plot()
    plt.show()

# %%
test_run()
# Out:
# 0     25.662767
# 2012-12-26  106947700
# 2012-12-27  167920600
# 2012-12-28  148806700
# 2012-12-31  243935200
# 2013-01-02  192059000
# 2013-01-03  144761800
# 2013-01-04  116817700
# 2013-01-07  110002500
# 2013-01-08  121265100
# 2013-01-09   90745600
# 2013-01-10  130735400
# 2013-01-11  113917300
# 2013-01-14   89567200
# ...               ...
# 2017-10-19   61903800
# 2017-10-20   89176400
# 2017-10-23   63915300
# 2017-10-24   66935900
# 2017-10-25  103715300
# 2017-10-26   69798000
# 2017-10-27   85562500
# 2017-10-30   54285700
# 2017-10-31   60304800
# 2017-11-01   54202700
# 2017-11-02   56449500
# 2017-11-03   59589700
# 2017-11-06   49652600
# 2017-11-07   57502200
# 2017-11-08   50469600
# 2017-11-09   95085500
# 2017-11-10   59984700
# 2017-11-13   50228600
# 2017-11-14   61315200
# 2017-11-15   80811500
# 2017-11-16   67777000
# 2017-11-17   75756800
# 2017-11-20   48075500
# 2017-11-21   69176800
# 2017-11-22   45033400
# 2017-11-24   27856500
# 2017-11-27   52274900
# 2017-11-28   98971700
# 2017-11-29   77512100
# 2017-11-30  122980900
#
# [1260 rows x 6 columns]

# %%
def empty_dataframe():
    start_date='01-12-2012'
    end_date='01-12-2017'
    date=pd.date_range(start_date,end_date)
    df1=pd.DataFrame(index=date)
   
    #read the Spy data into temporary dataframe
    dfSPY=pd.read_csv("data/SPY.csv",index_col="Date",parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
    #print(dfSPY)
    # Join the two dataframe using DataFrame.join()
    df1=df1.join(dfSPY)

    #print dataframe
    print(df1)

# %%
empty_dataframe()
# Out:
#              Adj Close
# 2012-01-12         NaN
# 2012-01-13         NaN
# 2012-01-14         NaN
# 2012-01-15         NaN
# 2012-01-16         NaN
# 2012-01-17         NaN
# 2012-01-18         NaN
# 2012-01-19         NaN
# 2012-01-20         NaN
# 2012-01-21         NaN
# 2012-01-22         NaN
# 2012-01-23         NaN
# 2012-01-24         NaN
# 2012-01-25         NaN
# 2012-01-26         NaN
# 2012-01-27         NaN
# 2012-01-28         NaN
# 2012-01-29         NaN
# 2012-01-30         NaN
# 2012-01-31         NaN
# 2012-02-01         NaN
# 2012-02-02         NaN
# 2012-02-03         NaN
# 2012-02-04         NaN
# 2012-02-05         NaN
# 2012-02-06         NaN
# 2012-02-07         NaN
# 2012-02-08         NaN
# 2012-02-09         NaN
# 2012-02-10         NaN
# ...                ...
# 2016-12-14  221.399963
# 2016-12-15  222.311523
# 2016-12-16  221.876724
# 2016-12-17         NaN
# 2016-12-18         NaN
# 2016-12-19  222.359833
# 2016-12-20  223.217606
# 2016-12-21  222.596466
# 2016-12-22  222.211945
# 2016-12-23  222.537308
# 2016-12-24         NaN
# 2016-12-25         NaN
# 2016-12-26         NaN
# 2016-12-27  223.089447
# 2016-12-28  221.245697
# 2016-12-29  221.196426
# 2016-12-30  220.387939
# 2016-12-31         NaN
# 2017-01-01         NaN
# 2017-01-02         NaN
# 2017-01-03  222.073914
# 2017-01-04  223.395081
# 2017-01-05  223.217606
# 2017-01-06  224.016220
# 2017-01-07         NaN
# 2017-01-08         NaN
# 2017-01-09  223.276779
# 2017-01-10  223.276779
# 2017-01-11  223.907761
# 2017-01-12  223.345779
#
# [1828 rows x 1 columns]

# %%
def empty_dataframe():
    start_date='01-12-2012'
    end_date='01-12-2017'
    date=pd.date_range(start_date,end_date)
    df1=pd.DataFrame(index=date)
   
    #read the Spy data into temporary dataframe
    dfSPY=pd.read_csv("data/SPY.csv",index_col="Date",parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
    
    # Join the two dataframe using DataFrame.join()
    df1=df1.join(dfSPY)
    df1=df1.dropna()
    #print dataframe
    print(df1)

#print dataframe
empty_dataframe()
# Out:
#              Adj Close
# 2012-11-30  128.334595
# 2012-12-03  127.702637
# 2012-12-04  127.522049
# 2012-12-05  127.747765
# 2012-12-06  128.181091
# 2012-12-07  128.569290
# 2012-12-10  128.623474
# 2012-12-11  129.499207
# 2012-12-12  129.562393
# 2012-12-13  128.767944
# 2012-12-14  128.289444
# 2012-12-17  129.797150
# 2012-12-18  131.241653
# 2012-12-19  130.266586
# 2012-12-20  131.015930
# 2012-12-21  129.826675
# 2012-12-24  129.426620
# 2012-12-26  128.881104
# 2012-12-27  128.708344
# 2012-12-28  127.317230
# 2012-12-31  129.481186
# 2013-01-02  132.799774
# 2013-01-03  132.499771
# 2013-01-04  133.081680
# 2013-01-07  132.718002
# 2013-01-08  132.336105
# 2013-01-09  132.672501
# 2013-01-10  133.727203
# 2013-01-11  133.718124
# 2013-01-14  133.627228
# ...                ...
# 2016-11-30  216.009033
# 2016-12-01  215.215134
# 2016-12-02  215.322937
# 2016-12-05  216.616745
# 2016-12-06  217.302887
# 2016-12-07  220.145355
# 2016-12-08  220.684448
# 2016-12-09  222.017456
# 2016-12-12  221.762619
# 2016-12-13  223.242661
# 2016-12-14  221.399963
# 2016-12-15  222.311523
# 2016-12-16  221.876724
# 2016-12-19  222.359833
# 2016-12-20  223.217606
# 2016-12-21  222.596466
# 2016-12-22  222.211945
# 2016-12-23  222.537308
# 2016-12-27  223.089447
# 2016-12-28  221.245697
# 2016-12-29  221.196426
# 2016-12-30  220.387939
# 2017-01-03  222.073914
# 2017-01-04  223.395081
# 2017-01-05  223.217606
# 2017-01-06  224.016220
# 2017-01-09  223.276779
# 2017-01-10  223.276779
# 2017-01-11  223.907761
# 2017-01-12  223.345779
#
# [1037 rows x 1 columns]

# %%
def empty_dataframe():
    start_date='01-12-2012'
    end_date='01-12-2017'
    date=pd.date_range(start_date,end_date)
    df1=pd.DataFrame(index=date)
   
    #read the Spy data into temporary dataframe
    dfSPY=pd.read_csv("data/SPY.csv",index_col="Date",parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
    dfSPY=dfSPY.rename(columns={'Adj Close':'SPY'})
    # Join the two dataframe using DataFrame.join()
    df1=df1.join(dfSPY,how='inner')

    #Read in more stocks
    symbols=['GOOG','IBM','GLD']
    for symbol in symbols:
        df_temp=pd.read_csv("data/{}.csv".format(symbol),index_col='Date',parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
        #rename to prevent clash
        df_temp=df_temp.rename(columns={'Adj Close':symbol})
# 2016-12-30  220.387939  771.820007  159.792236  109.610001
# 2017-01-03  222.073914  786.140015  160.947433  110.470001
# 2017-01-04  223.395081  786.900024  162.940125  110.860001
# 2017-01-05  223.217606  794.020020  162.401047  112.580002
# 2017-01-06  224.016220  806.150024  163.200043  111.750000
# 2017-01-09  223.276779  806.650024  161.390244  112.669998
# 2017-01-10  223.276779  804.789978  159.339783  113.150002
# 2017-01-11  223.907761  807.909973  161.486526  113.500000
# 2017-01-12  223.345779  806.359985  161.679047  113.910004
#
# [1037 rows x 4 columns]

# %%
"""Utility functions"""

import os
import pandas as pd

def symbol_to_path(symbol, base_dir="data"):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp=pd.read_csv(symbol_to_path(symbol),index_col='Date',parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
        df_temp=df_temp.rename(columns={'Adj Close':symbol})
        df=df.join(df_temp)
        if symbol == 'SPY':
            df=df.dropna(subset=['SPY'])
        # TODO: Read and join data for each symbol

    return df


def test_run():
    # Define a date range
    dates = pd.date_range('2013-01-22', '2013-01-26')

    # Choose stock symbols to read
    symbols = ['GOOG', 'IBM', 'GLD']
    
    # Get stock data
    df = get_data(symbols, dates)
    print (df)


if __name__ == "__main__":
    test_run()
# Out:
#                    SPY        GOOG         IBM         GLD
# 2013-01-22  135.591141  349.164032  168.633835  163.669998
# 2013-01-23  135.809311  368.354218  176.064468  163.210007
# 2013-01-24  135.845688  374.668152  175.806442  161.419998
# 2013-01-25  136.609436  374.399902  176.279495  160.649994

# %%
"""Utility functions"""

import os
import pandas as pd

def symbol_to_path(symbol, base_dir="data"):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp=pd.read_csv(symbol_to_path(symbol),index_col='Date',parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
        df_temp=df_temp.rename(columns={'Adj Close':symbol})
        df=df.join(df_temp)
        if symbol == 'SPY':
            df=df.dropna(subset=['SPY'])
        # TODO: Read and join data for each symbol

    return df


def test_run():
    # Define a date range
    dates = pd.date_range('2013-01-22', '2014-01-26')

    # Choose stock symbols to read
    symbols = ['GOOG', 'IBM', 'GLD']
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # slicing by row range 
    print (df.ix['2013-02-01':'2013-02-28'])


if __name__ == "__main__":
    test_run()
# Out:
#                    SPY        GOOG         IBM         GLD
# 2013-02-01  137.509537  385.294037  176.460068  161.449997
# 2013-02-04  135.963882  377.057617  175.264618  162.000000
# 2013-02-05  137.336807  380.395905  174.404617  161.960007
# 2013-02-06  137.436829  382.596588  173.610077  162.389999
# 2013-02-07  137.254990  384.474365  172.504578  161.839996
# 2013-02-08  138.018723  390.147461  174.180069  161.570007
# 2013-02-11  137.991425  388.682007  172.867310  159.699997
# 2013-02-12  138.218719  387.827545  172.763687  159.889999
# 2013-02-13  138.336899  388.900574  172.806885  159.050003
# 2013-02-14  138.464203  391.364563  172.426849  158.350006
# 2013-02-15  138.300568  393.883179  173.575500  155.759995
# 2013-02-19  139.337082  400.818054  173.005524  155.330002
# 2013-02-20  137.600464  393.669556  172.133209  151.440002
# 2013-02-21  136.763992  395.194641  171.286835  152.619995
# 2013-02-22  138.100525  397.271149  173.670517  152.970001
# 2013-02-25  135.472931  392.830017  170.578659  154.339996
# 2013-02-26  136.400284  392.512085  171.986420  156.220001
# 2013-02-27  138.118744  397.305908  174.741425  154.570007
# 2013-02-28  137.845963  398.011322  173.445984  153.000000
# C:\Users\Pulkit\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
"""Utility functions"""

import os
import pandas as pd

def symbol_to_path(symbol, base_dir="data"):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp=pd.read_csv(symbol_to_path(symbol),index_col='Date',parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
        df_temp=df_temp.rename(columns={'Adj Close':symbol})
        df=df.join(df_temp)
        if symbol == 'SPY':
            df=df.dropna(subset=['SPY'])
        # TODO: Read and join data for each symbol

    return df


def test_run():
    # Define a date range
    dates = pd.date_range('2013-01-22', '2014-01-26')

    # Choose stock symbols to read
    symbols = ['GOOG', 'IBM', 'GLD']
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # slicing by row range 
    print (df.loc['2013-02-01':'2013-02-28',['SPY','GOOG']])


if __name__ == "__main__":
    test_run()
# Out:
#                    SPY        GOOG
# 2013-02-01  137.509537  385.294037
# 2013-02-04  135.963882  377.057617
# 2013-02-05  137.336807  380.395905
# 2013-02-06  137.436829  382.596588
# 2013-02-07  137.254990  384.474365
# 2013-02-08  138.018723  390.147461
# 2013-02-11  137.991425  388.682007
# 2013-02-12  138.218719  387.827545
# 2013-02-13  138.336899  388.900574
# 2013-02-14  138.464203  391.364563
# 2013-02-15  138.300568  393.883179
# 2013-02-19  139.337082  400.818054
# 2013-02-20  137.600464  393.669556
# 2013-02-21  136.763992  395.194641
# 2013-02-22  138.100525  397.271149
# 2013-02-25  135.472931  392.830017
# 2013-02-26  136.400284  392.512085
# 2013-02-27  138.118744  397.305908
# 2013-02-28  137.845963  398.011322

# %%
"""Utility functions"""

import os
import pandas as pd

def symbol_to_path(symbol, base_dir="data"):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp=pd.read_csv(symbol_to_path(symbol),index_col='Date',parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
        df_temp=df_temp.rename(columns={'Adj Close':symbol})
        df=df.join(df_temp)
        if symbol == 'SPY':
            df=df.dropna(subset=['SPY'])
        # TODO: Read and join data for each symbol

    return df


def test_run():
    # Define a date range
    dates = pd.date_range('2013-01-22', '2014-01-26')

    # Choose stock symbols to read
    symbols = ['GOOG', 'IBM', 'GLD']
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # slicing by row range 
    print (df.plot())
    plt.show()


if __name__ == "__main__":
    test_run()
# Out:
# Axes(0.125,0.2;0.775x0.68)

# %%
"""Utility functions"""

import os
import pandas as pd

def symbol_to_path(symbol, base_dir="data"):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp=pd.read_csv(symbol_to_path(symbol),index_col='Date',parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
        df_temp=df_temp.rename(columns={'Adj Close':symbol})
        df=df.join(df_temp)
        if symbol == 'SPY':
            df=df.dropna(subset=['SPY'])
        # TODO: Read and join data for each symbol

    return df

def plot_df(df,title="Stocks Price"):
    ax=df.plot(title=title,fontsize=2)
    ax.set_xlabel('Date')
    ax.set_ylabel('Stocks')
    plt.show()
    
    
def test_run():
    # Define a date range
    dates = pd.date_range('2013-01-22', '2014-01-26')

    # Choose stock symbols to read
    symbols = ['GOOG', 'IBM', 'GLD']
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # slicing by row range 
    plot_df(df)


if __name__ == "__main__":
    test_run()

# %%
"""Utility functions"""

import os
import pandas as pd

def symbol_to_path(symbol, base_dir="data"):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp=pd.read_csv(symbol_to_path(symbol),index_col='Date',parse_dates=True,usecols=['Date','Adj Close'],na_values=['nan'])
        df_temp=df_temp.rename(columns={'Adj Close':symbol})
        df=df.join(df_temp)
        if symbol == 'SPY':
            df=df.dropna(subset=['SPY'])
        # TODO: Read and join data for each symbol

    return df

def normalize_data(df):
    return df/df.iloc[0,:]

def plot_df(df,title="Stocks Price"):
    ax=df.plot(title=title,fontsize=12)
    ax.set_xlabel('Date')
    ax.set_ylabel('Stocks')
    plt.show()
    
def test_run():
    # Define a date range
    dates = pd.date_range('2013-01-22', '2014-01-26')

    # Choose stock symbols to read
    symbols = ['GOOG', 'IBM', 'GLD']
    
    # Get stock data
    df = get_data(symbols, dates)
    
    plot_df(df)
    normalize_data(df)
    plot_df(df)


if __name__ == "__main__":
    test_run()
